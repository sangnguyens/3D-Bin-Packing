# %% [markdown]
# # Bin rendering of agent trained using a rectangular bin for 1000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_01k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-18-45.pt-2022.08.23-00-53-22/trajs.npy
# Out:
# ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_01k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-18-45.pt-2022.08.23-00-53-22/trajs.npy

# %%
# !cat ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_01k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-18-45.pt-2022.08.23-00-53-22/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.55789, mean length 22.12000

# %%
eval_data_path = '../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_01k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-18-45.pt-2022.08.23-00-53-22/trajs.npy'

renderBin(eval_data_path, case = -1)
# Out:
# ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_01k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-18-45.pt-2022.08.23-00-53-22/trajs.npy
# 18

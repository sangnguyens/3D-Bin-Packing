# %% [markdown]
# # Bin rendering of agent trained using a rectangular bin for 2000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_02k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-30-37.pt-2022.08.23-00-55-19/trajs.npy
# Out:
# ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_02k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-30-37.pt-2022.08.23-00-55-19/trajs.npy

# %%
# !cat ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_02k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-30-37.pt-2022.08.23-00-55-19/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.73763, mean length 28.99000

# %%
eval_data_path = '../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_02k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-30-37.pt-2022.08.23-00-55-19/trajs.npy'

renderBin(eval_data_path, case = -1)
# Out:
# ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_02k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-13-30-37.pt-2022.08.23-00-55-19/trajs.npy
# 40

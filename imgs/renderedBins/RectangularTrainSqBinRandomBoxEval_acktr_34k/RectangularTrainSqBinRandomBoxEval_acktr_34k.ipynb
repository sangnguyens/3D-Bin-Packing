# %% [markdown]
# # Bin rendering of agent trained using a rectangular bin for 34000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_34k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-19-30-13.pt-2022.08.23-05-55-13/trajs.npy
# Out:
# ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_34k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-19-30-13.pt-2022.08.23-05-55-13/trajs.npy

# %%
# !cat ../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_34k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-19-30-13.pt-2022.08.23-05-55-13/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.73274, mean length 28.52000

# %%
eval_data_path = '../../logs/evaluation/RectangularTrainSqBinRandomBoxEval_acktr_34k.log___PCT-Discrete_acktr_20x10x10Bin_s42_inh_800_defaultBox-2022.08.18-13-06-52_2022.08.18-19-30-13.pt-2022.08.23-05-55-13/trajs.npy'
renderBin(eval_data_path, case = -1)
# Out:
# 32

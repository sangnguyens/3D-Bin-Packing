# %% [markdown]
# # Bin rendering of agent trained using a rectangular bin for 1000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/SqBinFlatBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-05-46/trajs.npy
# Out:
# ../../logs/evaluation/SqBinFlatBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-05-46/trajs.npy

# %%
# !cat ../../logs/evaluation/SqBinFlatBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-05-46/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.65958, mean length 5.38000

# %%
eval_data_path = '../../logs/evaluation/SqBinFlatBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-05-46/trajs.npy'

renderBin(eval_data_path, case = -1)
# Out:
# ../../logs/evaluation/SqBinFlatBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-05-46/trajs.npy
# 5

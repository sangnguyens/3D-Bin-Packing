# %% [markdown]
# # Bin rendering of agent trained using a rectangular bin for 2000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/SqBinFlatBoxEval_acktr_02k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-00-10-07.pt-2022.08.23-05-12-33/trajs.npy
# Out:
# ../../logs/evaluation/SqBinFlatBoxEval_acktr_02k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-00-10-07.pt-2022.08.23-05-12-33/trajs.npy

# %%
# !cat ../../logs/evaluation/SqBinFlatBoxEval_acktr_02k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-00-10-07.pt-2022.08.23-05-12-33/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.64001, mean length 5.20000

# %%
eval_data_path = '../../logs/evaluation/SqBinFlatBoxEval_acktr_02k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-00-10-07.pt-2022.08.23-05-12-33/trajs.npy'


renderBin(eval_data_path, case = -1)
# Out:
# ../../logs/evaluation/SqBinFlatBoxEval_acktr_02k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-00-10-07.pt-2022.08.23-05-12-33/trajs.npy
# 5

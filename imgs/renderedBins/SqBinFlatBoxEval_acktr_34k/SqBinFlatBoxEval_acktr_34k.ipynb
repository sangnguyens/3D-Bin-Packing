# %% [markdown]
# # Bin rendering of agent trained for 34000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/SqBinFlatBoxEval_acktr_34k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-06-02-10.pt-2022.08.23-01-08-47/trajs.npy
# Out:
# ../../logs/evaluation/SqBinFlatBoxEval_acktr_34k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-06-02-10.pt-2022.08.23-01-08-47/trajs.npy

# %%
# !cat ../../logs/evaluation/SqBinFlatBoxEval_acktr_34k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-06-02-10.pt-2022.08.23-01-08-47/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.67057, mean length 5.60000

# %%
eval_data_path = '../../logs/evaluation/SqBinFlatBoxEval_acktr_34k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.20-06-02-10.pt-2022.08.23-01-08-47/trajs.npy'


renderBin(eval_data_path, case = -1)
# Out:
# 5

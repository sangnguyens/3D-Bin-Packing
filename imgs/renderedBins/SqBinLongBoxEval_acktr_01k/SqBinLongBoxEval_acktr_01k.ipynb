# %% [markdown]
# # Bin rendering of agent trained for 1000 updates

# %%
# %%capture
# %%run BinRenderingCode.ipynb

import nbimporter
from BinRenderingCode import renderBin

# %%
# !ls ../../logs/evaluation/SqBinLongBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-01-17/trajs.npy
# Out:
# ../../logs/evaluation/SqBinLongBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-01-17/trajs.npy

# %%
# !cat ../../logs/evaluation/SqBinLongBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-01-17/result.txt
# Out:
# Evaluation using 100 episodes
# Mean ratio 0.66248, mean length 21.32000

# %%
eval_data_path = '../../logs/evaluation/SqBinLongBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-01-17/trajs.npy'

renderBin(eval_data_path, case = -1)
# Out:
# ../../logs/evaluation/SqBinLongBoxEval_acktr_01k.log___PCT-Discrete_acktr_10x10x10Bin_s42_inh_800_defaultBox-2022.08.19-23-47-51_2022.08.19-23-59-01.pt-2022.08.23-01-01-17/trajs.npy
# 26
